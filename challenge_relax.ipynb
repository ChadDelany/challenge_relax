# %% [markdown]
# # Challenge: Relax, Inc.

# %% [markdown]
# created on Google Colab.

# %% [markdown]
# ## Load Libraries & Data

# %%
# Import Standard Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from datetime import datetime

# %%
#Import Modeling Libraries
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import minmax_scale

from sklearn.model_selection import train_test_split

from sklearn.svm import SVC

from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import matthews_corrcoef as mmc

# %%
# Accessing Google Drive by mounting it locally
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Location on Google Drive
repo = 'challenge_relax'
# %cd /content/drive/MyDrive/colab_notebooks/GitHub/{repo}/

# Load data files into pandas
users = pd.read_csv('takehome_users.csv', encoding = 'ISO-8859-1')
engagement = pd.read_csv('takehome_user_engagement.csv')
# Out:
# /content/drive/MyDrive/colab_notebooks/GitHub/challenge_relax

# %%
# Unmount Google Drive.
drive.flush_and_unmount()

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Users Dataframe

# %%
# Initial look at data.
users.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
# Initial stats of the data.
users.describe()
# Out:
#          object_id  last_session_creation_time  opted_in_to_mailing_list  \
# count  12000.00000                8.823000e+03              12000.000000
# mean    6000.50000                1.379279e+09                  0.249500
# std     3464.24595                1.953116e+07                  0.432742
# min        1.00000                1.338452e+09                  0.000000
# 25%     3000.75000                1.363195e+09                  0.000000
# 50%     6000.50000                1.382888e+09                  0.000000
# 75%     9000.25000                1.398443e+09                  0.000000
# max    12000.00000                1.402067e+09                  1.000000
#
#        enabled_for_marketing_drip        org_id  invited_by_user_id
# count                12000.000000  12000.000000         6417.000000
# mean                     0.149333    141.884583         5962.957145
# std                      0.356432    124.056723         3383.761968
# ...

# %%
# Characterizing the NaN within the data.
users.isna().sum()
# Out:
# object_id                        0
# creation_time                    0
# name                             0
# email                            0
# creation_source                  0
# last_session_creation_time    3177
# opted_in_to_mailing_list         0
# enabled_for_marketing_drip       0
# org_id                           0
# invited_by_user_id            5583
# dtype: int64

# %%
# Initial datatypes and non-null values.
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  object
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  8823 non-null   float64
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          6417 non-null   float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 937.6+ KB

# %%
# No way to quickly model the NaN values, so will fill with zero in this version of the model.
users = users.fillna(0)

# %%
# convert creation_time to datetime datatype.
users.creation_time = pd.to_datetime(users.creation_time)

# %%
# convert unix time of last_session_creation_time to datetime datatype.
users.last_session_creation_time = users.last_session_creation_time.map(lambda x: datetime.fromtimestamp(int(x)).strftime('%Y-%m-%d %H:%M:%S'))
users.last_session_creation_time = pd.to_datetime(users.last_session_creation_time)

# %%
# check conversion.
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   object_id                   12000 non-null  int64
#  1   creation_time               12000 non-null  datetime64[ns]
#  2   name                        12000 non-null  object
#  3   email                       12000 non-null  object
#  4   creation_source             12000 non-null  object
#  5   last_session_creation_time  12000 non-null  datetime64[ns]
#  6   opted_in_to_mailing_list    12000 non-null  int64
#  7   enabled_for_marketing_drip  12000 non-null  int64
#  8   org_id                      12000 non-null  int64
#  9   invited_by_user_id          12000 non-null  float64
# dtypes: datetime64[ns](2), float64(1), int64(4), object(3)
# memory usage: 937.6+ KB

# %%
users.head()
# Out:
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE        2014-04-22 03:53:30
# 1      MatthewPoole@gustr.com      ORG_INVITE        2014-03-31 03:45:04
# 2  MitchellBottrill@gustr.com      ORG_INVITE        2013-03-19 23:14:52
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE        2013-05-22 08:09:28
# 4          GraceRaw@yahoo.com    GUEST_INVITE        2013-01-22 10:14:20
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %% [markdown]
# ### Engagement Dataframe

# %%
engagement.head()
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %%
engagement.describe()
# Out:
#              user_id   visited
# count  207917.000000  207917.0
# mean     5913.314197       1.0
# std      3394.941674       0.0
# min         1.000000       1.0
# 25%      3087.000000       1.0
# 50%      5682.000000       1.0
# 75%      8944.000000       1.0
# max     12000.000000       1.0

# %%
# Characterize NaN values
engagement.isna().sum()
# Out:
# time_stamp    0
# user_id       0
# visited       0
# dtype: int64

# %%
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  object
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ MB

# %%
# convert object datatype to datetime datatype
engagement.time_stamp = pd.to_datetime(engagement.time_stamp)

# %%
# check conversion
engagement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207917 entries, 0 to 207916
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time_stamp  207917 non-null  datetime64[ns]
#  1   user_id     207917 non-null  int64
#  2   visited     207917 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 4.8 MB

# %% [markdown]
# ## EDA & Pre-processing

# %%
# We can figure out longevity in days by subtracting the creation date with the last log session.

longevity_days = users.last_session_creation_time - users.creation_time

days = []
for i in longevity_days:
    val = i.days
    if val < 0:
        days.append(0)
    else:
        days.append(val)

users['longevity_days'] = days

# %%
users.head()
# Out:
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE        2014-04-22 03:53:30
# 1      MatthewPoole@gustr.com      ORG_INVITE        2014-03-31 03:45:04
# 2  MitchellBottrill@gustr.com      ORG_INVITE        2013-03-19 23:14:52
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE        2013-05-22 08:09:28
# 4          GraceRaw@yahoo.com    GUEST_INVITE        2013-01-22 10:14:20
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
# Need to determine "adopted users" - as a user who has logged into the product on three separate days in at least one seven­day period.
# Defining a function that gives a count for each group.

def get_count(group, freq):
    return group.rolling(freq, on='time_stamp')['user_id'].count()

engagement['visits_7_days'] = engagement.groupby('user_id', as_index=False, group_keys=False).apply(get_count, '7D')

# %%
engagement.head()
# Out:
#            time_stamp  user_id  visited  visits_7_days
# 0 2014-04-22 03:53:30        1        1            1.0
# 1 2013-11-15 03:45:04        2        1            1.0
# 2 2013-11-29 03:45:04        2        1            1.0
# 3 2013-12-09 03:45:04        2        1            1.0
# 4 2013-12-25 03:45:04        2        1            1.0

# %%
# Need to determine Adopted User status

engagement_counts = []

for i, j in engagement.iterrows():
    if j.visits_7_days >= 3.0:
        if j.user_id not in engagement_counts:
            engagement_counts.append(j.user_id)

# %%
adopted_user = []

for i in users.object_id:
    if i in engagement_counts:
        adopted_user.append(1)
    else:
        adopted_user.append(0)

# %%
users['adopted_user'] = adopted_user

# %%
users.head()
# Out:
#    object_id       creation_time               name  \
# 0          1 2014-04-22 03:53:30     Clausen August
# 1          2 2013-11-15 03:45:04      Poole Matthew
# 2          3 2013-03-19 23:14:52  Bottrill Mitchell
# 3          4 2013-05-21 08:09:28    Clausen Nicklas
# 4          5 2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE        2014-04-22 03:53:30
# 1      MatthewPoole@gustr.com      ORG_INVITE        2014-03-31 03:45:04
# 2  MitchellBottrill@gustr.com      ORG_INVITE        2013-03-19 23:14:52
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE        2013-05-22 08:09:28
# 4          GraceRaw@yahoo.com    GUEST_INVITE        2013-01-22 10:14:20
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
# Number of adopted users.
(users.adopted_user == 1).sum()
# Out:
# 1602

# %%
# Encode variables
LE = LabelEncoder()
users['creation_source_code'] = LE.fit_transform(users.creation_source)

# %%
# Define independent and dependent variables
y = users.adopted_user
indep_var = users.drop(['object_id', 'name', 'email', 'creation_source', 'creation_time', 'last_session_creation_time', 'adopted_user'], axis=1)
indep_var_cols = indep_var.columns

# Scale data
X = minmax_scale(indep_var)

# %%
# Train / Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=73)
